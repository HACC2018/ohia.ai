# %%
import os, re, glob
os.environ['CUDA_DEVICE_ORDER']='PCI_BUS_ID'
os.environ['CUDA_VISIBLE_DEVICES']='0'

import numpy as np
import pandas as pd
import tensorflowjs as tfjs

from keras import layers, Model, callbacks
from keras.optimizers import Adam
from keras.applications.mobilenetv2 import MobileNetV2
from sklearn.model_selection import train_test_split
from ohia.metrics import top_1_accuracy, top_3_accuracy, top_5_accuracy
from ohia.encoders import FastLabelEncoder
from ohia.utils import PlantNetGenerator
# Out:
# Using TensorFlow backend.

# %%
SEED = 0
BATCH_SIZE = 64
MODEL_NAME = 'mobilenetv2'
FILE_PATH = '/home/matt/repos/ohia.ai/data'
IMAGE_DIR = 'resized_images'

# %%
# get list of images and labels
file_list = glob.glob(f'{FILE_PATH}/{IMAGE_DIR}/**/*.jpg', recursive=True)
full_label_list = [re.split('/', f)[-2] for f in file_list]
full_label_ids = FastLabelEncoder().fit_transform(full_label_list)

# %%
# split data
train_files, valid_files, train_ids, valid_ids \
    = train_test_split(file_list, full_label_ids, test_size=0.1, random_state=SEED)

# %%
# create generators
n_classes = len(np.unique(full_label_list))
train_generator = PlantNetGenerator(train_files, train_ids, n_classes, BATCH_SIZE, augment=True)
valid_generator = PlantNetGenerator(valid_files, valid_ids, n_classes, BATCH_SIZE, augment=False)

# %%
# load pretrained ImageNet model
base_model = MobileNetV2(
    input_shape=(224,224,3),
    weights='imagenet',
    include_top=False
)

# set freeze all layers
for layer in base_model.layers:
    layer.trainable = False
    
# map ImageNet features to 39 plants
x = base_model.output
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(1024, activation='relu')(x)
outputs = layers.Dense(n_classes, activation='softmax')(x)
    
# compile the model
model = Model(inputs=base_model.input, outputs=outputs)
model.compile(
    optimizer=Adam(lr=0.0001),
    loss='categorical_crossentropy',
    metrics=[top_1_accuracy, top_3_accuracy, top_5_accuracy]
)

# define callbacks
callbacks_list = [
    callbacks.EarlyStopping(
        monitor='val_top_3_accuracy',
        patience=10,
        verbose=1,
        mode='max',
    ),
    callbacks.ReduceLROnPlateau(
        monitor='val_top_3_accuracy',
        factor=0.5,
        patience=3,
        verbose=1,
        mode='max',
    ),
    callbacks.ModelCheckpoint(
        monitor='val_top_3_accuracy',
        filepath=f'{FILE_PATH}/weights/{MODEL_NAME}.h5',
        save_best_only=True,
        save_weights_only=True,
        mode='max',
    ),
]

# train model
model.fit_generator(
    generator=train_generator,
    validation_data=valid_generator,
    callbacks=callbacks_list,
    use_multiprocessing=True,
    workers=20,
    epochs=100,    
)
# Out:
# Epoch 1/100
# 165/165 [==============================] - 53s 324ms/step - loss: 1.9786 - top_1_accuracy: 0.4469 - top_3_accuracy: 0.6581 - top_5_accuracy: 0.7597 - val_loss: 1.8654 - val_top_1_accuracy: 0.4627 - val_top_3_accuracy: 0.6719 - val_top_5_accuracy: 0.7760
# Epoch 2/100
# 165/165 [==============================] - 45s 274ms/step - loss: 1.2630 - top_1_accuracy: 0.6366 - top_3_accuracy: 0.8360 - top_5_accuracy: 0.9011 - val_loss: 1.6380 - val_top_1_accuracy: 0.5156 - val_top_3_accuracy: 0.7413 - val_top_5_accuracy: 0.83429 - top_3_acc
# Epoch 3/100
# 165/165 [==============================] - 48s 293ms/step - loss: 1.0736 - top_1_accuracy: 0.6824 - top_3_accuracy: 0.8730 - top_5_accuracy: 0.9299 - val_loss: 1.7294 - val_top_1_accuracy: 0.5156 - val_top_3_accuracy: 0.7370 - val_top_5_accuracy: 0.8342
# Epoch 4/100
# 165/165 [==============================] - 53s 319ms/step - loss: 0.9838 - top_1_accuracy: 0.7091 - top_3_accuracy: 0.8867 - top_5_accuracy: 0.9411 - val_loss: 1.6672 - val_top_1_accuracy: 0.5139 - val_top_3_accuracy: 0.7691 - val_top_5_accuracy: 0.8559
# Epoch 5/100
# 165/165 [==============================] - 55s 332ms/step - loss: 0.9025 - top_1_accuracy: 0.7304 - top_3_accuracy: 0.9005 - top_5_accuracy: 0.9482 - val_loss: 1.6158 - val_top_1_accuracy: 0.5339 - val_top_3_accuracy: 0.7656 - val_top_5_accuracy: 0.8542
# Epoch 6/100
# 165/165 [==============================] - 51s 307ms/step - loss: 0.8453 - top_1_accuracy: 0.7471 - top_3_accuracy: 0.9146 - top_5_accuracy: 0.9545 - val_loss: 1.6494 - val_top_1_accuracy: 0.5234 - val_top_3_accuracy: 0.7552 - val_top_5_accuracy: 0.8524
# Epoch 6/100Epoch 7/100
# 165/165 [==============================] - 53s 324ms/step - loss: 0.8103 - top_1_accuracy: 0.7616 - top_3_accuracy: 0.9184 - top_5_accuracy: 0.9598 - val_loss: 1.5513 - val_top_1_accuracy: 0.5469 - val_top_3_accuracy: 0.7856 - val_top_5_accuracy: 0.8785
# Epoch 8/100
# 165/165 [==============================] - 50s 303ms/step - loss: 0.7648 - top_1_accuracy: 0.7724 - top_3_accuracy: 0.9230 - top_5_accuracy: 0.9634 - val_loss: 1.6077 - val_top_1_accuracy: 0.5295 - val_top_3_accuracy: 0.7656 - val_top_5_accuracy: 0.8516
# Epoch 9/100
# 165/165 [==============================] - 52s 314ms/step - loss: 0.7296 - top_1_accuracy: 0.7862 - top_3_accuracy: 0.9333 - top_5_accuracy: 0.9674 - val_loss: 1.6712 - val_top_1_accuracy: 0.5399 - val_top_3_accuracy: 0.7587 - val_top_5_accuracy: 0.8516
# Epoch 10/100
# 165/165 [==============================] - 50s 306ms/step - loss: 0.7033 - top_1_accuracy: 0.7931 - top_3_accuracy: 0.9369 - top_5_accuracy: 0.9705 - val_loss: 1.5678 - val_top_1_accuracy: 0.5530 - val_top_3_accuracy: 0.7795 - val_top_5_accuracy: 0.8585
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 11/100
# 165/165 [==============================] - 44s 267ms/step - loss: 0.6515 - top_1_accuracy: 0.8073 - top_3_accuracy: 0.9440 - top_5_accuracy: 0.9752 - val_loss: 1.6823 - val_top_1_accuracy: 0.5286 - val_top_3_accuracy: 0.7691 - val_top_5_accuracy: 0.8646
# Epoch 12/100
# 165/165 [==============================] - 49s 295ms/step - loss: 0.6314 - top_1_accuracy: 0.8142 - top_3_accuracy: 0.9488 - top_5_accuracy: 0.9777 - val_loss: 1.6509 - val_top_1_accuracy: 0.5243 - val_top_3_accuracy: 0.7760 - val_top_5_accuracy: 0.8663
# Epoch 13/100
# 165/165 [==============================] - 52s 316ms/step - loss: 0.6238 - top_1_accuracy: 0.8183 - top_3_accuracy: 0.9473 - top_5_accuracy: 0.9766 - val_loss: 1.6154 - val_top_1_accuracy: 0.5486 - val_top_3_accuracy: 0.7795 - val_top_5_accuracy: 0.8637
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 14/100
# 164/165 [============================>.] - ETA: 0s - loss: 0.5966 - top_1_accuracy: 0.8290 - top_3_accuracy: 0.9519 - top_5_accuracy: 0.9794 - ETA: 52s - loss: 0.
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 14/100
# 165/165 [==============================] - 51s 311ms/step - loss: 0.5967 - top_1_accuracy: 0.8291 - top_3_accuracy: 0.9517 - top_5_accuracy: 0.9793 - val_loss: 1.5971 - val_top_1_accuracy: 0.5564 - val_top_3_accuracy: 0.7752 - val_top_5_accuracy: 0.8707
# Epoch 15/100
# 164/165 [============================>.] - ETA: 0s - loss: 0.5989 - top_1_accuracy: 0.8282 - top_3_accuracy: 0.9541 - top_5_accuracy: 0.9809Epoch 15/100
# 165/165 [==============================] - 52s 317ms/step - loss: 0.5993 - top_1_accuracy: 0.8283 - top_3_accuracy: 0.9539 - top_5_accuracy: 0.9810 - val_loss: 1.5854 - val_top_1_accuracy: 0.5521 - val_top_3_accuracy: 0.7786 - val_top_5_accuracy: 0.8698
# Epoch 16/100
# 165/165 [==============================] - 52s 313ms/step - loss: 0.5915 - top_1_accuracy: 0.8259 - top_3_accuracy: 0.9525 - top_5_accuracy: 0.9785 - val_loss: 1.5917 - val_top_1_accuracy: 0.5590 - val_top_3_accuracy: 0.7873 - val_top_5_accuracy: 0.8724
# Epoch 17/100
# 165/165 [==============================] - 50s 306ms/step - loss: 0.5827 - top_1_accuracy: 0.8275 - top_3_accuracy: 0.9560 - top_5_accuracy: 0.9826 - val_loss: 1.6387 - val_top_1_accuracy: 0.5451 - val_top_3_accuracy: 0.7769 - val_top_5_accuracy: 0.8646
# Epoch 18/100
# 164/165 [============================>.] - ETA: 0s - loss: 0.5796 - top_1_accuracy: 0.8323 - top_3_accuracy: 0.9543 - top_5_accuracy: 0.9790
# 165/165 [==============================] - 53s 322ms/step - loss: 0.5792 - top_1_accuracy: 0.8326 - top_3_accuracy: 0.9544 - top_5_accuracy: 0.9791 - val_loss: 1.6472 - val_top_1_accuracy: 0.5312 - val_top_3_accuracy: 0.7821 - val_top_5_accuracy: 0.8681
# Epoch 19/100
# 165/165 [==============================] - 51s 311ms/step - loss: 0.5682 - top_1_accuracy: 0.8389 - top_3_accuracy: 0.9565 - top_5_accuracy: 0.9814 - val_loss: 1.6283 - val_top_1_accuracy: 0.5356 - val_top_3_accuracy: 0.7856 - val_top_5_accuracy: 0.8672_accuracy: 0.8404 - top_3_accuracy: 0.9570 - top_5_ - ETA: 5s - loss: 0.5715 - top_1_accuracy: 0.8395 - top_3_a
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 20/100
# 124/165 [=====================>........] - ETA: 11s - loss: 0.5597 - top_1_accuracy: 0.8420 - top_3_accuracy: 0.9567 - top_5_accuracy: 0.9811
# Process ForkPoolWorker-1322:
# Process ForkPoolWorker-1331:
# Process ForkPoolWorker-1329:
# Process ForkPoolWorker-1330:
# Process ForkPoolWorker-1314:
# Process ForkPoolWorker-1324:
# Process ForkPoolWorker-1323:
# Process ForkPoolWorker-1316:
# Process ForkPoolWorker-1328:
# Process ForkPoolWorker-1321:
# Process ForkPoolWorker-1319:
# Process ForkPoolWorker-1326:
# Process ForkPoolWorker-1327:
# Process ForkPoolWorker-1332:
# Process ForkPoolWorker-1313:
# Process ForkPoolWorker-1318:
# Process ForkPoolWorker-1309:
# Process ForkPoolWorker-1320:
# Process ForkPoolWorker-1312:
# Process ForkPoolWorker-1315:
# Process ForkPoolWorker-1317:
# Process ForkPoolWorker-1325:
# Process ForkPoolWorker-1308:
# Process ForkPoolWorker-1293:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-d26cd552089d> in <module>()
#      55     use_multiprocessing=True,
#      56     workers=20,
# ---> 57     epochs=100,
#      58 )
#
# ~/anaconda3/envs/kaggle/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~/anaconda3/envs/kaggle/lib/python3.6/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1416             use_multiprocessing=use_multiprocessing,
#    1417             shuffle=shuffle,
# -> 1418             initial_epoch=initial_epoch)
#    1419
#    1420     @interfaces.legacy_generator_methods_support
#
# ~/anaconda3/envs/kaggle/lib/python3.6/site-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     215                 outs = model.train_on_batch(x, y,
#     216                                             sample_weight=sample_weight,
# --> 217                                             class_weight=class_weight)
#     218
#     219                 outs = to_list(outs)
#
# ~/anaconda3/envs/kaggle/lib/python3.6/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1215             ins = x + y + sample_weights
#    1216         self._make_train_function()
# -> 1217         outputs = self.train_function(ins)
#    1218         return unpack_singleton(outputs)
#    1219
#
# ~/anaconda3/envs/kaggle/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~/anaconda3/envs/kaggle/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2653                 array_vals.append(
#    2654                     np.asarray(value,
# -> 2655                                dtype=tf.as_dtype(tensor.dtype).as_numpy_dtype))
#    2656         if self.feed_dict:
#    2657             for key in sorted(self.feed_dict.keys()):
#
# ~/anaconda3/envs/kaggle/lib/python3.6/site-packages/numpy/core/numeric.py in asarray(a, dtype, order)
#     499
#     500     """
# --> 501     return array(a, dtype, copy=False, order=order)
#     502
#     503
#
# KeyboardInterrupt:
# Process ForkPoolWorker-1307:
# Traceback (most recent call last):
# Process ForkPoolWorker-1311:
# Process ForkPoolWorker-1299:
# Process ForkPoolWorker-1301:
# Process ForkPoolWorker-1303:
# Traceback (most recent call last):
# Process ForkPoolWorker-1302:
# Process ForkPoolWorker-1298:
# Process ForkPoolWorker-1304:
# Process ForkPoolWorker-1294:
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Process ForkPoolWorker-1306:
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-1297:
# Process ForkPoolWorker-1300:
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Process ForkPoolWorker-1295:
# Process ForkPoolWorker-1310:
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# Traceback (most recent call last):
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Process ForkPoolWorker-1296:
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# Traceback (most recent call last):
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# Traceback (most recent call last):
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# Traceback (most recent call last):
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# Traceback (most recent call last):
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/pool.py", line 125, in worker
#     put((job, i, result))
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/queues.py", line 347, in put
#     self._writer.send_bytes(obj)
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# KeyboardInterrupt
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/pool.py", line 125, in worker
#     put((job, i, result))
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/pool.py", line 125, in worker
#     put((job, i, result))
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/connection.py", line 200, in send_bytes
#     self._send_bytes(m[offset:offset + size])
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/site-packages/keras/utils/data_utils.py", line 401, in get_index
#     return _SHARED_SEQUENCES[uid][i]
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/queues.py", line 346, in put
#     with self._wlock:
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/connection.py", line 398, in _send_bytes
#     self._send(buf)
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/matt/repos/ohia.ai/machine_learning/ohia/utils.py", line 137, in __getitem__
#     X[i] = img
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/site-packages/keras/utils/data_utils.py", line 401, in get_index
#     return _SHARED_SEQUENCES[uid][i]
# KeyboardInterrupt
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/pool.py", line 125, in worker
#     put((job, i, result))
# KeyboardInterrupt
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/queues.py", line 346, in put
#     with self._wlock:
# KeyboardInterrupt
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/queues.py", line 346, in put
#     with self._wlock:
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
#   File "/home/matt/repos/ohia.ai/machine_learning/ohia/utils.py", line 132, in __getitem__
#     img = crop_square(img, 'triangular')
# KeyboardInterrupt
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# KeyboardInterrupt
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/matt/repos/ohia.ai/machine_learning/ohia/utils.py", line 90, in crop_square
#     img = img.crop((0, c-w//2, w, c+w//2))
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# Process ForkPoolWorker-1305:
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/site-packages/PIL/Image.py", line 1090, in crop
#     self.load()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/site-packages/PIL/ImageFile.py", line 235, in load
#     n, err_code = decoder.decode(b)
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/connection.py", line 368, in _send
#     n = write(self._handle, buf)
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/pool.py", line 108, in worker
#     task = get()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/site-packages/keras/utils/data_utils.py", line 401, in get_index
#     return _SHARED_SEQUENCES[uid][i]
# KeyboardInterrupt
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/matt/repos/ohia.ai/machine_learning/ohia/utils.py", line 137, in __getitem__
#     X[i] = img
# KeyboardInterrupt
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/pool.py", line 125, in worker
#     put((job, i, result))
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/queues.py", line 341, in put
#     obj = _ForkingPickler.dumps(obj)
#   File "/home/matt/anaconda3/envs/kaggle/lib/python3.6/multiprocessing/reduction.py", line 51, in dumps
#     cls(buf, protocol).dump(obj)
# KeyboardInterrupt

# %%
# save model
model.load_weights(f'{FILE_PATH}/weights/{MODEL_NAME}.h5')
tfjs.converters.save_keras_model(model, f'{FILE_PATH}/models/{MODEL_NAME}')
